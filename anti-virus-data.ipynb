# %%
import requests
import pandas as pd
import numpy as np
import time

# ChEMBL API endpoints
ACTIVITY_URL = "https://www.ebi.ac.uk/chembl/api/data/activity.json"
TARGET_URL = "https://www.ebi.ac.uk/chembl/api/data/target"
UNIPROT_URL = "https://www.uniprot.org/uniprot/{}.fasta"

# Parameters
NUM_PAIRS = 30000  # Target number of virus-drug interactions
BATCH_SIZE = 1000  # Fetch data in batches
RETRY_LIMIT = 3  # Number of retries for API requests


def request_with_retry(url):
    """Handles API requests with retries for SSL errors, timeouts, and connection errors."""
    for attempt in range(RETRY_LIMIT):
        try:
            response = requests.get(url, timeout=10)
            if response.status_code == 200:
                return response  # Return response if successful
        except (requests.exceptions.SSLError, 
                requests.exceptions.ConnectionError, 
                requests.exceptions.Timeout) as e:
            print(f"⚠️ Request error: {e}, retrying ({attempt+1}/{RETRY_LIMIT})...")
            time.sleep(2)  # Wait before retrying
    
    return None  # Return None if all retries fail


def get_virus_activity(offset=0, limit=BATCH_SIZE):
    """Fetches activity data and filters for virus targets with IC50 values."""
    url = f"{ACTIVITY_URL}?limit={limit}&offset={offset}"
    response = request_with_retry(url)
    
    if not response:
        return []  # Return empty list if request fails

    try:
        activities = response.json().get("activities", [])
    except ValueError:
        print("⚠️ Failed to parse JSON from response.")
        return []

    filtered_activities = []
    for act in activities:
        organism = act.get("target_organism", "")
        ic50_value = act.get("standard_value")
        standard_type = act.get("standard_type")

        if organism and "virus" in organism.lower() and standard_type == "IC50" and ic50_value:
            try:
                ic50_value = float(ic50_value)
                if ic50_value > 0:  # Ensure valid IC50 values
                    pIC50 = -np.log10(ic50_value * 1e-9)  # Convert nM to M, then -log10
                    act["pIC50"] = pIC50  # Store calculated pIC50
                    filtered_activities.append(act)
            except ValueError:
                continue  # Skip invalid values

    return filtered_activities


def get_protein_sequence(uniprot_id):
    """Fetches protein sequence from UniProt."""
    url = UNIPROT_URL.format(uniprot_id)
    response = request_with_retry(url)

    if not response:
        return None  # Return None if request fails

    try:
        lines = response.text.split("\n")
        return "".join(lines[1:])  # Ignore FASTA header
    except Exception:
        return None  # Handle parsing errors



def fetch_data(offset):
    """Fetches virus-drug interactions and stores them in a structured dataset."""
    data = []
    activities = get_virus_activity(offset, BATCH_SIZE)
    if not activities:
        return None  # Stop if no more data

    for act in activities:
        target_id = act.get("target_chembl_id")
        drug_smiles = act.get("canonical_smiles")
        organism_name = act.get("target_pref_name")
        pIC50 = act.get("pIC50")

        if target_id and drug_smiles and pIC50:
           
            # Get target protein sequence
            target_response = request_with_retry(f"{TARGET_URL}/{target_id}.json")
            
            if target_response:
                try:
                    target_data = target_response.json()
                    target_components = target_data.get("target_components", [])
                    
                    if target_components:  # Ensure non-empty list
                        uniprot_id = target_components[0].get("accession")
                        
                        if uniprot_id:
                            sequence = get_protein_sequence(uniprot_id)
                            if sequence:
                                data.append([organism_name, sequence, drug_smiles, pIC50])
                except ValueError:
                    print(f"⚠️ Failed to parse JSON for target {target_id}.")
    return data

# %%
all_data=[]
offset = 0
while(len(all_data)<NUM_PAIRS): 
    print(f"🔍 Fetching records from offset {offset} (Current size: {len(all_data)})")
    data = fetch_data(offset)
    if(data):
        all_data+=(data)
    offset += BATCH_SIZE  # Move to next batch
    time.sleep(1)  # Avoid hitting API rate limits

df = pd.DataFrame(all_data, columns=["Virus_Organism", "Protein_Sequence", "SMILES", "pIC50"])
# Save to CSV
df.to_csv(r"E:\anti\virus_drug_interactions.csv", index=False)
print("✅ Data saved to virus_drug_interactions.csv")
# Out:
# 🔍 Fetching records from offset 0 (Current size: 0)
# 🔍 Fetching records from offset 1000 (Current size: 8)
# 🔍 Fetching records from offset 2000 (Current size: 18)
# 🔍 Fetching records from offset 3000 (Current size: 27)
# 🔍 Fetching records from offset 4000 (Current size: 39)
# 🔍 Fetching records from offset 5000 (Current size: 48)
# 🔍 Fetching records from offset 6000 (Current size: 57)
# 🔍 Fetching records from offset 7000 (Current size: 67)
# 🔍 Fetching records from offset 8000 (Current size: 81)
# 🔍 Fetching records from offset 9000 (Current size: 97)
# 🔍 Fetching records from offset 10000 (Current size: 106)
# 🔍 Fetching records from offset 11000 (Current size: 114)
# 🔍 Fetching records from offset 12000 (Current size: 124)
# 🔍 Fetching records from offset 13000 (Current size: 128)
# 🔍 Fetching records from offset 14000 (Current size: 139)
# 🔍 Fetching records from offset 15000 (Current size: 152)
# 🔍 Fetching records from offset 16000 (Current size: 157)
# 🔍 Fetching records from offset 17000 (Current size: 176)
# 🔍 Fetching records from offset 18000 (Current size: 183)
# 🔍 Fetching records from offset 19000 (Current size: 188)
# 🔍 Fetching records from offset 20000 (Current size: 213)
# 🔍 Fetching records from offset 21000 (Current size: 225)
# 🔍 Fetching records from offset 22000 (Current size: 237)
# 🔍 Fetching records from offset 23000 (Current size: 250)
# 🔍 Fetching records from offset 24000 (Current size: 264)
# 🔍 Fetching records from offset 25000 (Current size: 267)
# 🔍 Fetching records from offset 26000 (Current size: 284)
# 🔍 Fetching records from offset 27000 (Current size: 302)
# 🔍 Fetching records from offset 28000 (Current size: 316)
# 🔍 Fetching records from offset 29000 (Current size: 321)
# 🔍 Fetching records from offset 30000 (Current size: 325)
# 🔍 Fetching records from offset 31000 (Current size: 344)
# 🔍 Fetching records from offset 32000 (Current size: 355)
# 🔍 Fetching records from offset 33000 (Current size: 361)
# 🔍 Fetching records from offset 34000 (Current size: 371)
# 🔍 Fetching records from offset 35000 (Current size: 387)
# 🔍 Fetching records from offset 36000 (Current size: 395)
# 🔍 Fetching records from offset 37000 (Current size: 407)
# 🔍 Fetching records from offset 38000 (Current size: 424)
# 🔍 Fetching records from offset 39000 (Current size: 435)
# 🔍 Fetching records from offset 40000 (Current size: 442)
# 🔍 Fetching records from offset 41000 (Current size: 444)
# 🔍 Fetching records from offset 42000 (Current size: 445)
# 🔍 Fetching records from offset 43000 (Current size: 449)
# 🔍 Fetching records from offset 44000 (Current size: 453)
# 🔍 Fetching records from offset 45000 (Current size: 459)
# 🔍 Fetching records from offset 46000 (Current size: 460)
# 🔍 Fetching records from offset 47000 (Current size: 463)
# 🔍 Fetching records from offset 48000 (Current size: 467)
# 🔍 Fetching records from offset 49000 (Current size: 468)
# 🔍 Fetching records from offset 50000 (Current size: 470)
# 🔍 Fetching records from offset 51000 (Current size: 476)
# 🔍 Fetching records from offset 52000 (Current size: 477)
# 🔍 Fetching records from offset 53000 (Current size: 479)
# 🔍 Fetching records from offset 54000 (Current size: 485)
# 🔍 Fetching records from offset 55000 (Current size: 491)
# 🔍 Fetching records from offset 56000 (Current size: 493)
# 🔍 Fetching records from offset 57000 (Current size: 494)
# 🔍 Fetching records from offset 58000 (Current size: 496)
# 🔍 Fetching records from offset 59000 (Current size: 503)
# 🔍 Fetching records from offset 60000 (Current size: 505)
# 🔍 Fetching records from offset 61000 (Current size: 505)
# 🔍 Fetching records from offset 62000 (Current size: 505)
# 🔍 Fetching records from offset 63000 (Current size: 508)
# 🔍 Fetching records from offset 64000 (Current size: 512)
# 🔍 Fetching records from offset 65000 (Current size: 517)
# 🔍 Fetching records from offset 66000 (Current size: 517)
# 🔍 Fetching records from offset 67000 (Current size: 519)
# 🔍 Fetching records from offset 68000 (Current size: 521)
# 🔍 Fetching records from offset 69000 (Current size: 524)
# 🔍 Fetching records from offset 70000 (Current size: 526)
# 🔍 Fetching records from offset 71000 (Current size: 531)
# 🔍 Fetching records from offset 72000 (Current size: 531)
# 🔍 Fetching records from offset 73000 (Current size: 532)
# 🔍 Fetching records from offset 74000 (Current size: 546)
# 🔍 Fetching records from offset 75000 (Current size: 556)
# 🔍 Fetching records from offset 76000 (Current size: 571)
# 🔍 Fetching records from offset 77000 (Current size: 598)
# 🔍 Fetching records from offset 78000 (Current size: 616)
# 🔍 Fetching records from offset 79000 (Current size: 634)
# 🔍 Fetching records from offset 80000 (Current size: 653)
# 🔍 Fetching records from offset 81000 (Current size: 655)
# 🔍 Fetching records from offset 82000 (Current size: 668)
# 🔍 Fetching records from offset 83000 (Current size: 693)
# 🔍 Fetching records from offset 84000 (Current size: 708)
# 🔍 Fetching records from offset 85000 (Current size: 723)
# 🔍 Fetching records from offset 86000 (Current size: 746)
# 🔍 Fetching records from offset 87000 (Current size: 767)
# 🔍 Fetching records from offset 88000 (Current size: 789)
# 🔍 Fetching records from offset 89000 (Current size: 801)
# 🔍 Fetching records from offset 90000 (Current size: 820)
# 🔍 Fetching records from offset 91000 (Current size: 828)
# 🔍 Fetching records from offset 92000 (Current size: 851)
# 🔍 Fetching records from offset 93000 (Current size: 871)
# 🔍 Fetching records from offset 94000 (Current size: 885)
# 🔍 Fetching records from offset 95000 (Current size: 893)
# 🔍 Fetching records from offset 96000 (Current size: 904)
# 🔍 Fetching records from offset 97000 (Current size: 923)
# 🔍 Fetching records from offset 98000 (Current size: 947)
# 🔍 Fetching records from offset 99000 (Current size: 954)
# 🔍 Fetching records from offset 100000 (Current size: 981)
# 🔍 Fetching records from offset 101000 (Current size: 1000)
# 🔍 Fetching records from offset 102000 (Current size: 1017)
# 🔍 Fetching records from offset 103000 (Current size: 1029)
# 🔍 Fetching records from offset 104000 (Current size: 1047)
# 🔍 Fetching records from offset 105000 (Current size: 1065)
# 🔍 Fetching records from offset 106000 (Current size: 1080)
# 🔍 Fetching records from offset 107000 (Current size: 1103)
# 🔍 Fetching records from offset 108000 (Current size: 1124)
# 🔍 Fetching records from offset 109000 (Current size: 1147)
# 🔍 Fetching records from offset 110000 (Current size: 1161)
# 🔍 Fetching records from offset 111000 (Current size: 1182)
# 🔍 Fetching records from offset 112000 (Current size: 1187)
# 🔍 Fetching records from offset 113000 (Current size: 1213)
# 🔍 Fetching records from offset 114000 (Current size: 1222)
# 🔍 Fetching records from offset 115000 (Current size: 1228)
# 🔍 Fetching records from offset 116000 (Current size: 1232)
# 🔍 Fetching records from offset 117000 (Current size: 1239)
# 🔍 Fetching records from offset 118000 (Current size: 1252)
# 🔍 Fetching records from offset 119000 (Current size: 1260)
# 🔍 Fetching records from offset 120000 (Current size: 1262)
# 🔍 Fetching records from offset 121000 (Current size: 1267)
# 🔍 Fetching records from offset 122000 (Current size: 1273)
# 🔍 Fetching records from offset 123000 (Current size: 1284)
# 🔍 Fetching records from offset 124000 (Current size: 1294)
# 🔍 Fetching records from offset 125000 (Current size: 1299)
# 🔍 Fetching records from offset 126000 (Current size: 1303)
# 🔍 Fetching records from offset 127000 (Current size: 1307)
# 🔍 Fetching records from offset 128000 (Current size: 1312)
# 🔍 Fetching records from offset 129000 (Current size: 1317)
# 🔍 Fetching records from offset 130000 (Current size: 1322)
# 🔍 Fetching records from offset 131000 (Current size: 1331)
# 🔍 Fetching records from offset 132000 (Current size: 1332)
# 🔍 Fetching records from offset 133000 (Current size: 1335)
# 🔍 Fetching records from offset 134000 (Current size: 1342)
# 🔍 Fetching records from offset 135000 (Current size: 1352)
# 🔍 Fetching records from offset 136000 (Current size: 1355)
# 🔍 Fetching records from offset 137000 (Current size: 1364)
# 🔍 Fetching records from offset 138000 (Current size: 1372)
# 🔍 Fetching records from offset 139000 (Current size: 1381)
# 🔍 Fetching records from offset 140000 (Current size: 1388)
# 🔍 Fetching records from offset 141000 (Current size: 1392)
# 🔍 Fetching records from offset 142000 (Current size: 1404)
# 🔍 Fetching records from offset 143000 (Current size: 1416)
# 🔍 Fetching records from offset 144000 (Current size: 1422)
# 🔍 Fetching records from offset 145000 (Current size: 1431)
# 🔍 Fetching records from offset 146000 (Current size: 1440)
# 🔍 Fetching records from offset 147000 (Current size: 1446)
# 🔍 Fetching records from offset 148000 (Current size: 1449)
# 🔍 Fetching records from offset 149000 (Current size: 1452)
# 🔍 Fetching records from offset 150000 (Current size: 1459)
# 🔍 Fetching records from offset 151000 (Current size: 1473)
# 🔍 Fetching records from offset 152000 (Current size: 1476)
# 🔍 Fetching records from offset 153000 (Current size: 1483)
# 🔍 Fetching records from offset 154000 (Current size: 1490)
# 🔍 Fetching records from offset 155000 (Current size: 1498)
# 🔍 Fetching records from offset 156000 (Current size: 1504)
# 🔍 Fetching records from offset 157000 (Current size: 1510)
# 🔍 Fetching records from offset 158000 (Current size: 1518)
# 🔍 Fetching records from offset 159000 (Current size: 1522)
# 🔍 Fetching records from offset 160000 (Current size: 1528)
# 🔍 Fetching records from offset 161000 (Current size: 1535)
# 🔍 Fetching records from offset 162000 (Current size: 1549)
# 🔍 Fetching records from offset 163000 (Current size: 1554)
# 🔍 Fetching records from offset 164000 (Current size: 1566)
# 🔍 Fetching records from offset 165000 (Current size: 1574)
# 🔍 Fetching records from offset 166000 (Current size: 1580)
# 🔍 Fetching records from offset 167000 (Current size: 1588)
# 🔍 Fetching records from offset 168000 (Current size: 1595)
# 🔍 Fetching records from offset 169000 (Current size: 1604)
# 🔍 Fetching records from offset 170000 (Current size: 1612)
# 🔍 Fetching records from offset 171000 (Current size: 1630)
# 🔍 Fetching records from offset 172000 (Current size: 1643)
# 🔍 Fetching records from offset 173000 (Current size: 1653)
# ⚠️ Request error: HTTPSConnectionPool(host='rest.uniprot.org', port=443): Read timed out. (read timeout=10), retrying (1/3)...
# 🔍 Fetching records from offset 174000 (Current size: 1664)
# 🔍 Fetching records from offset 175000 (Current size: 1671)
# 🔍 Fetching records from offset 176000 (Current size: 1686)
# 🔍 Fetching records from offset 177000 (Current size: 1696)
# 🔍 Fetching records from offset 178000 (Current size: 1702)
# 🔍 Fetching records from offset 179000 (Current size: 1708)
# 🔍 Fetching records from offset 180000 (Current size: 1713)
# 🔍 Fetching records from offset 181000 (Current size: 1719)
# 🔍 Fetching records from offset 182000 (Current size: 1728)
# 🔍 Fetching records from offset 183000 (Current size: 1741)
# 🔍 Fetching records from offset 184000 (Current size: 1749)
# 🔍 Fetching records from offset 185000 (Current size: 1755)
# 🔍 Fetching records from offset 186000 (Current size: 1764)
# 🔍 Fetching records from offset 187000 (Current size: 1782)
# 🔍 Fetching records from offset 188000 (Current size: 1791)
# 🔍 Fetching records from offset 189000 (Current size: 1802)
# 🔍 Fetching records from offset 190000 (Current size: 1812)
# 🔍 Fetching records from offset 191000 (Current size: 1820)
# 🔍 Fetching records from offset 192000 (Current size: 1830)
# 🔍 Fetching records from offset 193000 (Current size: 1833)
# 🔍 Fetching records from offset 194000 (Current size: 1841)
# 🔍 Fetching records from offset 195000 (Current size: 1843)
# 🔍 Fetching records from offset 196000 (Current size: 1846)
# 🔍 Fetching records from offset 197000 (Current size: 1852)
# 🔍 Fetching records from offset 198000 (Current size: 1856)
# 🔍 Fetching records from offset 199000 (Current size: 1865)
# 🔍 Fetching records from offset 200000 (Current size: 1868)
# 🔍 Fetching records from offset 201000 (Current size: 1871)
# 🔍 Fetching records from offset 202000 (Current size: 1873)
# 🔍 Fetching records from offset 203000 (Current size: 1883)
# 🔍 Fetching records from offset 204000 (Current size: 1892)
# 🔍 Fetching records from offset 205000 (Current size: 1896)
# 🔍 Fetching records from offset 206000 (Current size: 1900)
# 🔍 Fetching records from offset 207000 (Current size: 1908)
# 🔍 Fetching records from offset 208000 (Current size: 1910)
# 🔍 Fetching records from offset 209000 (Current size: 1914)
# 🔍 Fetching records from offset 210000 (Current size: 1916)
# 🔍 Fetching records from offset 211000 (Current size: 1919)
# 🔍 Fetching records from offset 212000 (Current size: 1927)
# 🔍 Fetching records from offset 213000 (Current size: 1928)
# 🔍 Fetching records from offset 214000 (Current size: 1932)
# 🔍 Fetching records from offset 215000 (Current size: 1934)
# 🔍 Fetching records from offset 216000 (Current size: 1947)
# 🔍 Fetching records from offset 217000 (Current size: 1952)
# 🔍 Fetching records from offset 218000 (Current size: 1955)
# 🔍 Fetching records from offset 219000 (Current size: 1958)
# 🔍 Fetching records from offset 220000 (Current size: 1962)
# 🔍 Fetching records from offset 221000 (Current size: 1969)
# 🔍 Fetching records from offset 222000 (Current size: 1972)
# 🔍 Fetching records from offset 223000 (Current size: 1978)
# 🔍 Fetching records from offset 224000 (Current size: 1980)
# 🔍 Fetching records from offset 225000 (Current size: 1983)
# 🔍 Fetching records from offset 226000 (Current size: 1993)
# 🔍 Fetching records from offset 227000 (Current size: 1998)
# 🔍 Fetching records from offset 228000 (Current size: 2001)
# 🔍 Fetching records from offset 229000 (Current size: 2009)
# 🔍 Fetching records from offset 230000 (Current size: 2014)
# 🔍 Fetching records from offset 231000 (Current size: 2019)
# 🔍 Fetching records from offset 232000 (Current size: 2026)
# 🔍 Fetching records from offset 233000 (Current size: 2027)
# 🔍 Fetching records from offset 234000 (Current size: 2036)
# 🔍 Fetching records from offset 235000 (Current size: 2039)
# 🔍 Fetching records from offset 236000 (Current size: 2040)
# 🔍 Fetching records from offset 237000 (Current size: 2041)
# 🔍 Fetching records from offset 238000 (Current size: 2047)
# 🔍 Fetching records from offset 239000 (Current size: 2050)
# 🔍 Fetching records from offset 240000 (Current size: 2059)
# 🔍 Fetching records from offset 241000 (Current size: 2067)
# 🔍 Fetching records from offset 242000 (Current size: 2074)
# 🔍 Fetching records from offset 243000 (Current size: 2082)
# 🔍 Fetching records from offset 244000 (Current size: 2089)
# 🔍 Fetching records from offset 245000 (Current size: 2094)
# 🔍 Fetching records from offset 246000 (Current size: 2102)
# 🔍 Fetching records from offset 247000 (Current size: 2114)
# 🔍 Fetching records from offset 248000 (Current size: 2120)
# 🔍 Fetching records from offset 249000 (Current size: 2123)
# 🔍 Fetching records from offset 250000 (Current size: 2129)
# 🔍 Fetching records from offset 251000 (Current size: 2129)
# 🔍 Fetching records from offset 252000 (Current size: 2130)
# 🔍 Fetching records from offset 253000 (Current size: 2139)
# 🔍 Fetching records from offset 254000 (Current size: 2142)
# 🔍 Fetching records from offset 255000 (Current size: 2143)
# 🔍 Fetching records from offset 256000 (Current size: 2151)
# 🔍 Fetching records from offset 257000 (Current size: 2154)
# 🔍 Fetching records from offset 258000 (Current size: 2166)
# 🔍 Fetching records from offset 259000 (Current size: 2175)
# 🔍 Fetching records from offset 260000 (Current size: 2175)
# 🔍 Fetching records from offset 261000 (Current size: 2175)
# 🔍 Fetching records from offset 262000 (Current size: 2177)
# 🔍 Fetching records from offset 263000 (Current size: 2178)
# 🔍 Fetching records from offset 264000 (Current size: 2189)
# 🔍 Fetching records from offset 265000 (Current size: 2192)
# 🔍 Fetching records from offset 266000 (Current size: 2193)
# 🔍 Fetching records from offset 267000 (Current size: 2193)
# 🔍 Fetching records from offset 268000 (Current size: 2201)
# 🔍 Fetching records from offset 269000 (Current size: 2211)
# 🔍 Fetching records from offset 270000 (Current size: 2211)
# 🔍 Fetching records from offset 271000 (Current size: 2214)
# 🔍 Fetching records from offset 272000 (Current size: 2216)
# 🔍 Fetching records from offset 273000 (Current size: 2219)
# 🔍 Fetching records from offset 274000 (Current size: 2221)
# 🔍 Fetching records from offset 275000 (Current size: 2226)
# 🔍 Fetching records from offset 276000 (Current size: 2230)
# 🔍 Fetching records from offset 277000 (Current size: 2236)
# 🔍 Fetching records from offset 278000 (Current size: 2251)
# 🔍 Fetching records from offset 279000 (Current size: 2252)
# 🔍 Fetching records from offset 280000 (Current size: 2257)
# 🔍 Fetching records from offset 281000 (Current size: 2260)
# 🔍 Fetching records from offset 282000 (Current size: 2260)
# 🔍 Fetching records from offset 283000 (Current size: 2263)
# 🔍 Fetching records from offset 284000 (Current size: 2268)
# 🔍 Fetching records from offset 285000 (Current size: 2269)
# 🔍 Fetching records from offset 286000 (Current size: 2275)
# 🔍 Fetching records from offset 287000 (Current size: 2282)
# 🔍 Fetching records from offset 288000 (Current size: 2285)
# 🔍 Fetching records from offset 289000 (Current size: 2286)
# 🔍 Fetching records from offset 290000 (Current size: 2290)
# 🔍 Fetching records from offset 291000 (Current size: 2297)
# 🔍 Fetching records from offset 292000 (Current size: 2304)
# 🔍 Fetching records from offset 293000 (Current size: 2307)
# 🔍 Fetching records from offset 294000 (Current size: 2311)
# 🔍 Fetching records from offset 295000 (Current size: 2316)
# 🔍 Fetching records from offset 296000 (Current size: 2319)
# 🔍 Fetching records from offset 297000 (Current size: 2324)
# 🔍 Fetching records from offset 298000 (Current size: 2333)
# 🔍 Fetching records from offset 299000 (Current size: 2333)
# 🔍 Fetching records from offset 300000 (Current size: 2345)
# 🔍 Fetching records from offset 301000 (Current size: 2350)
# 🔍 Fetching records from offset 302000 (Current size: 2351)
# 🔍 Fetching records from offset 303000 (Current size: 2353)
# 🔍 Fetching records from offset 304000 (Current size: 2359)
# 🔍 Fetching records from offset 305000 (Current size: 2360)
# 🔍 Fetching records from offset 306000 (Current size: 2365)
# 🔍 Fetching records from offset 307000 (Current size: 2372)
# 🔍 Fetching records from offset 308000 (Current size: 2377)
# 🔍 Fetching records from offset 309000 (Current size: 2380)
# 🔍 Fetching records from offset 310000 (Current size: 2386)
# 🔍 Fetching records from offset 311000 (Current size: 2387)
# 🔍 Fetching records from offset 312000 (Current size: 2393)
# 🔍 Fetching records from offset 313000 (Current size: 2400)
# 🔍 Fetching records from offset 314000 (Current size: 2404)
# 🔍 Fetching records from offset 315000 (Current size: 2408)
# 🔍 Fetching records from offset 316000 (Current size: 2411)
# 🔍 Fetching records from offset 317000 (Current size: 2423)
# 🔍 Fetching records from offset 318000 (Current size: 2428)
# 🔍 Fetching records from offset 319000 (Current size: 2433)
# 🔍 Fetching records from offset 320000 (Current size: 2437)
# 🔍 Fetching records from offset 321000 (Current size: 2443)
# 🔍 Fetching records from offset 322000 (Current size: 2448)
# 🔍 Fetching records from offset 323000 (Current size: 2450)
# 🔍 Fetching records from offset 324000 (Current size: 2453)
# 🔍 Fetching records from offset 325000 (Current size: 2460)
# 🔍 Fetching records from offset 326000 (Current size: 2463)
# 🔍 Fetching records from offset 327000 (Current size: 2472)
# 🔍 Fetching records from offset 328000 (Current size: 2475)
# 🔍 Fetching records from offset 329000 (Current size: 2483)
# 🔍 Fetching records from offset 330000 (Current size: 2487)
# 🔍 Fetching records from offset 331000 (Current size: 2498)
# 🔍 Fetching records from offset 332000 (Current size: 2504)
# 🔍 Fetching records from offset 333000 (Current size: 2504)
# 🔍 Fetching records from offset 334000 (Current size: 2516)
# 🔍 Fetching records from offset 335000 (Current size: 2524)
# 🔍 Fetching records from offset 336000 (Current size: 2526)
# 🔍 Fetching records from offset 337000 (Current size: 2534)
# 🔍 Fetching records from offset 338000 (Current size: 2545)
# 🔍 Fetching records from offset 339000 (Current size: 2553)
# 🔍 Fetching records from offset 340000 (Current size: 2556)
# 🔍 Fetching records from offset 341000 (Current size: 2561)
# 🔍 Fetching records from offset 342000 (Current size: 2566)
# 🔍 Fetching records from offset 343000 (Current size: 2568)
# 🔍 Fetching records from offset 344000 (Current size: 2581)
# 🔍 Fetching records from offset 345000 (Current size: 2585)
# 🔍 Fetching records from offset 346000 (Current size: 2591)
# 🔍 Fetching records from offset 347000 (Current size: 2595)
# 🔍 Fetching records from offset 348000 (Current size: 2601)
# 🔍 Fetching records from offset 349000 (Current size: 2602)
# 🔍 Fetching records from offset 350000 (Current size: 2607)
# 🔍 Fetching records from offset 351000 (Current size: 2619)
# 🔍 Fetching records from offset 352000 (Current size: 2622)
# 🔍 Fetching records from offset 353000 (Current size: 2623)
# 🔍 Fetching records from offset 354000 (Current size: 2628)
# 🔍 Fetching records from offset 355000 (Current size: 2634)
# 🔍 Fetching records from offset 356000 (Current size: 2636)
# 🔍 Fetching records from offset 357000 (Current size: 2648)
# 🔍 Fetching records from offset 358000 (Current size: 2655)
# 🔍 Fetching records from offset 359000 (Current size: 2658)
# 🔍 Fetching records from offset 360000 (Current size: 2677)
# 🔍 Fetching records from offset 361000 (Current size: 2685)
# 🔍 Fetching records from offset 362000 (Current size: 2697)
# 🔍 Fetching records from offset 363000 (Current size: 2715)
# 🔍 Fetching records from offset 364000 (Current size: 2718)
# 🔍 Fetching records from offset 365000 (Current size: 2724)
# 🔍 Fetching records from offset 366000 (Current size: 2737)
# 🔍 Fetching records from offset 367000 (Current size: 2750)
# 🔍 Fetching records from offset 368000 (Current size: 2753)
# 🔍 Fetching records from offset 369000 (Current size: 2760)
# 🔍 Fetching records from offset 370000 (Current size: 2770)
# 🔍 Fetching records from offset 371000 (Current size: 2780)
# 🔍 Fetching records from offset 372000 (Current size: 2783)
# 🔍 Fetching records from offset 373000 (Current size: 2789)
# 🔍 Fetching records from offset 374000 (Current size: 2800)
# 🔍 Fetching records from offset 375000 (Current size: 2808)
# 🔍 Fetching records from offset 376000 (Current size: 2819)
# 🔍 Fetching records from offset 377000 (Current size: 2822)
# ⚠️ Request error: HTTPSConnectionPool(host='www.ebi.ac.uk', port=443): Read timed out. (read timeout=10), retrying (1/3)...
# 🔍 Fetching records from offset 378000 (Current size: 2828)
# 🔍 Fetching records from offset 379000 (Current size: 2847)
# 🔍 Fetching records from offset 380000 (Current size: 2851)
# 🔍 Fetching records from offset 381000 (Current size: 2858)
# 🔍 Fetching records from offset 382000 (Current size: 2870)
# 🔍 Fetching records from offset 383000 (Current size: 2876)
# 🔍 Fetching records from offset 384000 (Current size: 2880)
# 🔍 Fetching records from offset 385000 (Current size: 2888)
# 🔍 Fetching records from offset 386000 (Current size: 2892)
# 🔍 Fetching records from offset 387000 (Current size: 2897)
# 🔍 Fetching records from offset 388000 (Current size: 2899)
# 🔍 Fetching records from offset 389000 (Current size: 2904)
# 🔍 Fetching records from offset 390000 (Current size: 2919)
# 🔍 Fetching records from offset 391000 (Current size: 2926)
# 🔍 Fetching records from offset 392000 (Current size: 2931)
# 🔍 Fetching records from offset 393000 (Current size: 2939)
# 🔍 Fetching records from offset 394000 (Current size: 2953)
# 🔍 Fetching records from offset 395000 (Current size: 2967)
# 🔍 Fetching records from offset 396000 (Current size: 2979)
# 🔍 Fetching records from offset 397000 (Current size: 2988)
# 🔍 Fetching records from offset 398000 (Current size: 2995)
# 🔍 Fetching records from offset 399000 (Current size: 3000)
# 🔍 Fetching records from offset 400000 (Current size: 3012)
# 🔍 Fetching records from offset 401000 (Current size: 3015)
# 🔍 Fetching records from offset 402000 (Current size: 3024)
# 🔍 Fetching records from offset 403000 (Current size: 3041)
# 🔍 Fetching records from offset 404000 (Current size: 3059)
# 🔍 Fetching records from offset 405000 (Current size: 3075)
# 🔍 Fetching records from offset 406000 (Current size: 3079)
# 🔍 Fetching records from offset 407000 (Current size: 3098)
# 🔍 Fetching records from offset 408000 (Current size: 3111)
# 🔍 Fetching records from offset 409000 (Current size: 3124)
# 🔍 Fetching records from offset 410000 (Current size: 3134)
# 🔍 Fetching records from offset 411000 (Current size: 3142)
# 🔍 Fetching records from offset 412000 (Current size: 3165)
# 🔍 Fetching records from offset 413000 (Current size: 3182)
# 🔍 Fetching records from offset 414000 (Current size: 3186)
# 🔍 Fetching records from offset 415000 (Current size: 3196)
# 🔍 Fetching records from offset 416000 (Current size: 3200)
# 🔍 Fetching records from offset 417000 (Current size: 3203)
# 🔍 Fetching records from offset 418000 (Current size: 3208)
# 🔍 Fetching records from offset 419000 (Current size: 3216)
# 🔍 Fetching records from offset 420000 (Current size: 3223)
# 🔍 Fetching records from offset 421000 (Current size: 3244)
# 🔍 Fetching records from offset 422000 (Current size: 3246)
# 🔍 Fetching records from offset 423000 (Current size: 3253)
# 🔍 Fetching records from offset 424000 (Current size: 3276)
# 🔍 Fetching records from offset 425000 (Current size: 3280)
# 🔍 Fetching records from offset 426000 (Current size: 3285)
# 🔍 Fetching records from offset 427000 (Current size: 3293)
# 🔍 Fetching records from offset 428000 (Current size: 3297)
# 🔍 Fetching records from offset 429000 (Current size: 3301)
# 🔍 Fetching records from offset 430000 (Current size: 3310)
# 🔍 Fetching records from offset 431000 (Current size: 3316)
# 🔍 Fetching records from offset 432000 (Current size: 3327)
# 🔍 Fetching records from offset 433000 (Current size: 3331)
# 🔍 Fetching records from offset 434000 (Current size: 3352)
# 🔍 Fetching records from offset 435000 (Current size: 3358)
# 🔍 Fetching records from offset 436000 (Current size: 3363)
# 🔍 Fetching records from offset 437000 (Current size: 3377)
# 🔍 Fetching records from offset 438000 (Current size: 3388)
# 🔍 Fetching records from offset 439000 (Current size: 3399)
# 🔍 Fetching records from offset 440000 (Current size: 3409)
# 🔍 Fetching records from offset 441000 (Current size: 3427)
# 🔍 Fetching records from offset 442000 (Current size: 3441)
# 🔍 Fetching records from offset 443000 (Current size: 3454)
# 🔍 Fetching records from offset 444000 (Current size: 3471)
# 🔍 Fetching records from offset 445000 (Current size: 3488)
# 🔍 Fetching records from offset 446000 (Current size: 3504)
# ⚠️ Request error: HTTPSConnectionPool(host='www.ebi.ac.uk', port=443): Read timed out. (read timeout=10), retrying (1/3)...
# 🔍 Fetching records from offset 447000 (Current size: 3525)
# 🔍 Fetching records from offset 448000 (Current size: 3532)
# 🔍 Fetching records from offset 449000 (Current size: 3547)
# 🔍 Fetching records from offset 450000 (Current size: 3550)
# 🔍 Fetching records from offset 451000 (Current size: 3567)
# ⚠️ Request error: HTTPSConnectionPool(host='www.ebi.ac.uk', port=443): Read timed out. (read timeout=10), retrying (1/3)...
# 🔍 Fetching records from offset 452000 (Current size: 3590)
# 🔍 Fetching records from offset 453000 (Current size: 3599)
# 🔍 Fetching records from offset 454000 (Current size: 3606)
# 🔍 Fetching records from offset 455000 (Current size: 3616)
# 🔍 Fetching records from offset 456000 (Current size: 3627)
# 🔍 Fetching records from offset 457000 (Current size: 3641)
# 🔍 Fetching records from offset 458000 (Current size: 3657)
# 🔍 Fetching records from offset 459000 (Current size: 3677)
# 🔍 Fetching records from offset 460000 (Current size: 3694)
# 🔍 Fetching records from offset 461000 (Current size: 3709)
# 🔍 Fetching records from offset 462000 (Current size: 3716)
# 🔍 Fetching records from offset 463000 (Current size: 3720)
# 🔍 Fetching records from offset 464000 (Current size: 3734)
# 🔍 Fetching records from offset 465000 (Current size: 3742)
# 🔍 Fetching records from offset 466000 (Current size: 3757)
# 🔍 Fetching records from offset 467000 (Current size: 3770)
# 🔍 Fetching records from offset 468000 (Current size: 3783)
# 🔍 Fetching records from offset 469000 (Current size: 3803)
# 🔍 Fetching records from offset 470000 (Current size: 3817)
# 🔍 Fetching records from offset 471000 (Current size: 3836)
# 🔍 Fetching records from offset 472000 (Current size: 3850)
# 🔍 Fetching records from offset 473000 (Current size: 3860)
# 🔍 Fetching records from offset 474000 (Current size: 3881)
# 🔍 Fetching records from offset 475000 (Current size: 3888)
# 🔍 Fetching records from offset 476000 (Current size: 3898)
# 🔍 Fetching records from offset 477000 (Current size: 3918)
# 🔍 Fetching records from offset 478000 (Current size: 3937)
# 🔍 Fetching records from offset 479000 (Current size: 3944)
# 🔍 Fetching records from offset 480000 (Current size: 3962)
# 🔍 Fetching records from offset 481000 (Current size: 3972)
# 🔍 Fetching records from offset 482000 (Current size: 3976)
# 🔍 Fetching records from offset 483000 (Current size: 3985)
# 🔍 Fetching records from offset 484000 (Current size: 3989)
# 🔍 Fetching records from offset 485000 (Current size: 3999)
# 🔍 Fetching records from offset 486000 (Current size: 4003)
# 🔍 Fetching records from offset 487000 (Current size: 4011)
# 🔍 Fetching records from offset 488000 (Current size: 4022)
# 🔍 Fetching records from offset 489000 (Current size: 4025)
# 🔍 Fetching records from offset 490000 (Current size: 4030)
# 🔍 Fetching records from offset 491000 (Current size: 4039)
# 🔍 Fetching records from offset 492000 (Current size: 4048)
# 🔍 Fetching records from offset 493000 (Current size: 4058)
# 🔍 Fetching records from offset 494000 (Current size: 4068)
# 🔍 Fetching records from offset 495000 (Current size: 4072)
# 🔍 Fetching records from offset 496000 (Current size: 4084)
# 🔍 Fetching records from offset 497000 (Current size: 4093)
# 🔍 Fetching records from offset 498000 (Current size: 4102)
# 🔍 Fetching records from offset 499000 (Current size: 4111)
# 🔍 Fetching records from offset 500000 (Current size: 4129)
# 🔍 Fetching records from offset 501000 (Current size: 4131)
# 🔍 Fetching records from offset 502000 (Current size: 4138)
# 🔍 Fetching records from offset 503000 (Current size: 4145)
# 🔍 Fetching records from offset 504000 (Current size: 4159)
# 🔍 Fetching records from offset 505000 (Current size: 4161)
# 🔍 Fetching records from offset 506000 (Current size: 4168)
# 🔍 Fetching records from offset 507000 (Current size: 4175)
# 🔍 Fetching records from offset 508000 (Current size: 4186)
# 🔍 Fetching records from offset 509000 (Current size: 4198)
# 🔍 Fetching records from offset 510000 (Current size: 4206)
# 🔍 Fetching records from offset 511000 (Current size: 4213)
# 🔍 Fetching records from offset 512000 (Current size: 4218)
# 🔍 Fetching records from offset 513000 (Current size: 4222)
# 🔍 Fetching records from offset 514000 (Current size: 4229)
# 🔍 Fetching records from offset 515000 (Current size: 4239)
# 🔍 Fetching records from offset 516000 (Current size: 4250)
# 🔍 Fetching records from offset 517000 (Current size: 4255)
# 🔍 Fetching records from offset 518000 (Current size: 4265)
# 🔍 Fetching records from offset 519000 (Current size: 4276)
# 🔍 Fetching records from offset 520000 (Current size: 4276)
# 🔍 Fetching records from offset 521000 (Current size: 4281)
# 🔍 Fetching records from offset 522000 (Current size: 4291)
# 🔍 Fetching records from offset 523000 (Current size: 4304)
# 🔍 Fetching records from offset 524000 (Current size: 4311)
# 🔍 Fetching records from offset 525000 (Current size: 4325)
# 🔍 Fetching records from offset 526000 (Current size: 4333)
# 🔍 Fetching records from offset 527000 (Current size: 4348)
# 🔍 Fetching records from offset 528000 (Current size: 4352)
# 🔍 Fetching records from offset 529000 (Current size: 4366)
# 🔍 Fetching records from offset 530000 (Current size: 4371)
# 🔍 Fetching records from offset 531000 (Current size: 4386)
# 🔍 Fetching records from offset 532000 (Current size: 4399)
# 🔍 Fetching records from offset 533000 (Current size: 4400)
# 🔍 Fetching records from offset 534000 (Current size: 4406)
# 🔍 Fetching records from offset 535000 (Current size: 4416)
# 🔍 Fetching records from offset 536000 (Current size: 4430)
# 🔍 Fetching records from offset 537000 (Current size: 4443)
# 🔍 Fetching records from offset 538000 (Current size: 4446)
# 🔍 Fetching records from offset 539000 (Current size: 4458)
# 🔍 Fetching records from offset 540000 (Current size: 4470)
# 🔍 Fetching records from offset 541000 (Current size: 4479)
# 🔍 Fetching records from offset 542000 (Current size: 4488)
# 🔍 Fetching records from offset 543000 (Current size: 4499)
# 🔍 Fetching records from offset 544000 (Current size: 4501)
# 🔍 Fetching records from offset 545000 (Current size: 4513)
# 🔍 Fetching records from offset 546000 (Current size: 4529)
# 🔍 Fetching records from offset 547000 (Current size: 4543)
# 🔍 Fetching records from offset 548000 (Current size: 4563)
# 🔍 Fetching records from offset 549000 (Current size: 4573)
# 🔍 Fetching records from offset 550000 (Current size: 4586)
# 🔍 Fetching records from offset 551000 (Current size: 4600)
# 🔍 Fetching records from offset 552000 (Current size: 4619)
# 🔍 Fetching records from offset 553000 (Current size: 4629)
# 🔍 Fetching records from offset 554000 (Current size: 4649)
# 🔍 Fetching records from offset 555000 (Current size: 4656)
# 🔍 Fetching records from offset 556000 (Current size: 4667)
# 🔍 Fetching records from offset 557000 (Current size: 4681)
# 🔍 Fetching records from offset 558000 (Current size: 4687)
# 🔍 Fetching records from offset 559000 (Current size: 4699)
# 🔍 Fetching records from offset 560000 (Current size: 4717)
# 🔍 Fetching records from offset 561000 (Current size: 4721)
# 🔍 Fetching records from offset 562000 (Current size: 4733)
# 🔍 Fetching records from offset 563000 (Current size: 4743)
# 🔍 Fetching records from offset 564000 (Current size: 4760)
# 🔍 Fetching records from offset 565000 (Current size: 4777)
# 🔍 Fetching records from offset 566000 (Current size: 4795)
# 🔍 Fetching records from offset 567000 (Current size: 4807)
# 🔍 Fetching records from offset 568000 (Current size: 4825)
# 🔍 Fetching records from offset 569000 (Current size: 4843)
# 🔍 Fetching records from offset 570000 (Current size: 4858)
# 🔍 Fetching records from offset 571000 (Current size: 4872)
# 🔍 Fetching records from offset 572000 (Current size: 4885)
# 🔍 Fetching records from offset 573000 (Current size: 4899)
# 🔍 Fetching records from offset 574000 (Current size: 4926)
# 🔍 Fetching records from offset 575000 (Current size: 4941)
# 🔍 Fetching records from offset 576000 (Current size: 4958)
# 🔍 Fetching records from offset 577000 (Current size: 4968)
# 🔍 Fetching records from offset 578000 (Current size: 4988)
# 🔍 Fetching records from offset 579000 (Current size: 5012)
# 🔍 Fetching records from offset 580000 (Current size: 5036)
# 🔍 Fetching records from offset 581000 (Current size: 5053)
# 🔍 Fetching records from offset 582000 (Current size: 5064)
# 🔍 Fetching records from offset 583000 (Current size: 5080)
# 🔍 Fetching records from offset 584000 (Current size: 5094)
# 🔍 Fetching records from offset 585000 (Current size: 5108)
# 🔍 Fetching records from offset 586000 (Current size: 5118)
# 🔍 Fetching records from offset 587000 (Current size: 5135)
# 🔍 Fetching records from offset 588000 (Current size: 5153)
# 🔍 Fetching records from offset 589000 (Current size: 5159)
# 🔍 Fetching records from offset 590000 (Current size: 5183)
# 🔍 Fetching records from offset 591000 (Current size: 5196)
# 🔍 Fetching records from offset 592000 (Current size: 5209)
# 🔍 Fetching records from offset 593000 (Current size: 5221)
# 🔍 Fetching records from offset 594000 (Current size: 5236)
# 🔍 Fetching records from offset 595000 (Current size: 5267)
# 🔍 Fetching records from offset 596000 (Current size: 5280)
# 🔍 Fetching records from offset 597000 (Current size: 5302)
# 🔍 Fetching records from offset 598000 (Current size: 5324)
# 🔍 Fetching records from offset 599000 (Current size: 5328)
# 🔍 Fetching records from offset 600000 (Current size: 5343)
# 🔍 Fetching records from offset 601000 (Current size: 5349)
# 🔍 Fetching records from offset 602000 (Current size: 5351)
# 🔍 Fetching records from offset 603000 (Current size: 5356)
# 🔍 Fetching records from offset 604000 (Current size: 5360)
# 🔍 Fetching records from offset 605000 (Current size: 5365)
# 🔍 Fetching records from offset 606000 (Current size: 5379)
# 🔍 Fetching records from offset 607000 (Current size: 5386)
# 🔍 Fetching records from offset 608000 (Current size: 5395)
# 🔍 Fetching records from offset 609000 (Current size: 5403)
# 🔍 Fetching records from offset 610000 (Current size: 5410)
# 🔍 Fetching records from offset 611000 (Current size: 5424)
# 🔍 Fetching records from offset 612000 (Current size: 5430)
# 🔍 Fetching records from offset 613000 (Current size: 5441)
# 🔍 Fetching records from offset 614000 (Current size: 5454)
# 🔍 Fetching records from offset 615000 (Current size: 5462)
# 🔍 Fetching records from offset 616000 (Current size: 5464)
# 🔍 Fetching records from offset 617000 (Current size: 5478)
# 🔍 Fetching records from offset 618000 (Current size: 5489)
# 🔍 Fetching records from offset 619000 (Current size: 5499)
# 🔍 Fetching records from offset 620000 (Current size: 5508)
# 🔍 Fetching records from offset 621000 (Current size: 5511)
# 🔍 Fetching records from offset 622000 (Current size: 5514)
# 🔍 Fetching records from offset 623000 (Current size: 5522)
# 🔍 Fetching records from offset 624000 (Current size: 5528)
# 🔍 Fetching records from offset 625000 (Current size: 5533)
# 🔍 Fetching records from offset 626000 (Current size: 5541)
# 🔍 Fetching records from offset 627000 (Current size: 5551)
# 🔍 Fetching records from offset 628000 (Current size: 5554)
# 🔍 Fetching records from offset 629000 (Current size: 5563)
# 🔍 Fetching records from offset 630000 (Current size: 5566)
# 🔍 Fetching records from offset 631000 (Current size: 5570)
# 🔍 Fetching records from offset 632000 (Current size: 5577)
# 🔍 Fetching records from offset 633000 (Current size: 5584)
# 🔍 Fetching records from offset 634000 (Current size: 5597)
# 🔍 Fetching records from offset 635000 (Current size: 5599)
# 🔍 Fetching records from offset 636000 (Current size: 5605)
# 🔍 Fetching records from offset 637000 (Current size: 5613)
# 🔍 Fetching records from offset 638000 (Current size: 5623)
# 🔍 Fetching records from offset 639000 (Current size: 5640)
# 🔍 Fetching records from offset 640000 (Current size: 5644)
# 🔍 Fetching records from offset 641000 (Current size: 5645)
# 🔍 Fetching records from offset 642000 (Current size: 5649)
# 🔍 Fetching records from offset 643000 (Current size: 5649)
# 🔍 Fetching records from offset 644000 (Current size: 5651)
# 🔍 Fetching records from offset 645000 (Current size: 5656)
# 🔍 Fetching records from offset 646000 (Current size: 5662)
# 🔍 Fetching records from offset 647000 (Current size: 5666)
# 🔍 Fetching records from offset 648000 (Current size: 5666)
# 🔍 Fetching records from offset 649000 (Current size: 5670)
# 🔍 Fetching records from offset 650000 (Current size: 5673)
# 🔍 Fetching records from offset 651000 (Current size: 5675)
# 🔍 Fetching records from offset 652000 (Current size: 5678)
# 🔍 Fetching records from offset 653000 (Current size: 5681)
# 🔍 Fetching records from offset 654000 (Current size: 5682)
# 🔍 Fetching records from offset 655000 (Current size: 5683)
# 🔍 Fetching records from offset 656000 (Current size: 5685)
# 🔍 Fetching records from offset 657000 (Current size: 5687)
# 🔍 Fetching records from offset 658000 (Current size: 5691)
# 🔍 Fetching records from offset 659000 (Current size: 5692)
# 🔍 Fetching records from offset 660000 (Current size: 5698)
# 🔍 Fetching records from offset 661000 (Current size: 5716)
# 🔍 Fetching records from offset 662000 (Current size: 5716)
# 🔍 Fetching records from offset 663000 (Current size: 5719)
# 🔍 Fetching records from offset 664000 (Current size: 5721)
# 🔍 Fetching records from offset 665000 (Current size: 5726)
# 🔍 Fetching records from offset 666000 (Current size: 5735)
# 🔍 Fetching records from offset 667000 (Current size: 5737)
# 🔍 Fetching records from offset 668000 (Current size: 5741)
# 🔍 Fetching records from offset 669000 (Current size: 5748)
# 🔍 Fetching records from offset 670000 (Current size: 5752)
# 🔍 Fetching records from offset 671000 (Current size: 5754)
# 🔍 Fetching records from offset 672000 (Current size: 5757)
# 🔍 Fetching records from offset 673000 (Current size: 5759)
# 🔍 Fetching records from offset 674000 (Current size: 5769)
# 🔍 Fetching records from offset 675000 (Current size: 5777)
# 🔍 Fetching records from offset 676000 (Current size: 5780)
# 🔍 Fetching records from offset 677000 (Current size: 5783)
# 🔍 Fetching records from offset 678000 (Current size: 5786)
# 🔍 Fetching records from offset 679000 (Current size: 5791)
# 🔍 Fetching records from offset 680000 (Current size: 5794)
# 🔍 Fetching records from offset 681000 (Current size: 5795)
# 🔍 Fetching records from offset 682000 (Current size: 5804)
# 🔍 Fetching records from offset 683000 (Current size: 5811)
# 🔍 Fetching records from offset 684000 (Current size: 5816)
# 🔍 Fetching records from offset 685000 (Current size: 5820)
# 🔍 Fetching records from offset 686000 (Current size: 5824)
# 🔍 Fetching records from offset 687000 (Current size: 5832)
# 🔍 Fetching records from offset 688000 (Current size: 5835)
# 🔍 Fetching records from offset 689000 (Current size: 5843)
# 🔍 Fetching records from offset 690000 (Current size: 5854)
# 🔍 Fetching records from offset 691000 (Current size: 5863)
# 🔍 Fetching records from offset 692000 (Current size: 5873)
# 🔍 Fetching records from offset 693000 (Current size: 5881)
# 🔍 Fetching records from offset 694000 (Current size: 5885)
# 🔍 Fetching records from offset 695000 (Current size: 5888)
# 🔍 Fetching records from offset 696000 (Current size: 5898)
# 🔍 Fetching records from offset 697000 (Current size: 5906)
# 🔍 Fetching records from offset 698000 (Current size: 5917)
# 🔍 Fetching records from offset 699000 (Current size: 5922)
# 🔍 Fetching records from offset 700000 (Current size: 5927)
# 🔍 Fetching records from offset 701000 (Current size: 5937)
# 🔍 Fetching records from offset 702000 (Current size: 5941)
# 🔍 Fetching records from offset 703000 (Current size: 5948)
# 🔍 Fetching records from offset 704000 (Current size: 5954)
# 🔍 Fetching records from offset 705000 (Current size: 5956)
# 🔍 Fetching records from offset 706000 (Current size: 5963)
# 🔍 Fetching records from offset 707000 (Current size: 5970)
# 🔍 Fetching records from offset 708000 (Current size: 5980)
# 🔍 Fetching records from offset 709000 (Current size: 5980)
# 🔍 Fetching records from offset 710000 (Current size: 5985)
# ⚠️ Request error: HTTPSConnectionPool(host='www.ebi.ac.uk', port=443): Read timed out. (read timeout=10), retrying (1/3)...
# ⚠️ Request error: HTTPSConnectionPool(host='www.ebi.ac.uk', port=443): Max retries exceeded with url: /chembl/api/data/target/CHEMBL613132.json (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000016A604D8AD0>, 'Connection to www.ebi.ac.uk timed out. (connect timeout=10)')), retrying (2/3)...
# 🔍 Fetching records from offset 711000 (Current size: 5987)
# 🔍 Fetching records from offset 712000 (Current size: 5998)
# 🔍 Fetching records from offset 713000 (Current size: 6002)
# 🔍 Fetching records from offset 714000 (Current size: 6006)
# 🔍 Fetching records from offset 715000 (Current size: 6010)
# 🔍 Fetching records from offset 716000 (Current size: 6017)
# 🔍 Fetching records from offset 717000 (Current size: 6023)
# 🔍 Fetching records from offset 718000 (Current size: 6027)
# 🔍 Fetching records from offset 719000 (Current size: 6031)
# 🔍 Fetching records from offset 720000 (Current size: 6035)
# 🔍 Fetching records from offset 721000 (Current size: 6039)
# 🔍 Fetching records from offset 722000 (Current size: 6044)
# 🔍 Fetching records from offset 723000 (Current size: 6047)
# 🔍 Fetching records from offset 724000 (Current size: 6051)
# 🔍 Fetching records from offset 725000 (Current size: 6056)
# 🔍 Fetching records from offset 726000 (Current size: 6064)
# 🔍 Fetching records from offset 727000 (Current size: 6072)
# 🔍 Fetching records from offset 728000 (Current size: 6078)
# 🔍 Fetching records from offset 729000 (Current size: 6085)
# 🔍 Fetching records from offset 730000 (Current size: 6096)
# 🔍 Fetching records from offset 731000 (Current size: 6104)
# 🔍 Fetching records from offset 732000 (Current size: 6107)
# 🔍 Fetching records from offset 733000 (Current size: 6113)
# 🔍 Fetching records from offset 734000 (Current size: 6120)
# 🔍 Fetching records from offset 735000 (Current size: 6127)
# 🔍 Fetching records from offset 736000 (Current size: 6132)
# 🔍 Fetching records from offset 737000 (Current size: 6141)
# 🔍 Fetching records from offset 738000 (Current size: 6143)
# 🔍 Fetching records from offset 739000 (Current size: 6152)
# 🔍 Fetching records from offset 740000 (Current size: 6159)
# 🔍 Fetching records from offset 741000 (Current size: 6164)
# 🔍 Fetching records from offset 742000 (Current size: 6171)
# 🔍 Fetching records from offset 743000 (Current size: 6177)
# 🔍 Fetching records from offset 744000 (Current size: 6183)
# 🔍 Fetching records from offset 745000 (Current size: 6189)
# 🔍 Fetching records from offset 746000 (Current size: 6194)
# 🔍 Fetching records from offset 747000 (Current size: 6198)
# 🔍 Fetching records from offset 748000 (Current size: 6204)
# 🔍 Fetching records from offset 749000 (Current size: 6212)
# 🔍 Fetching records from offset 750000 (Current size: 6219)
# 🔍 Fetching records from offset 751000 (Current size: 6221)
# 🔍 Fetching records from offset 752000 (Current size: 6226)
# 🔍 Fetching records from offset 753000 (Current size: 6236)
# 🔍 Fetching records from offset 754000 (Current size: 6242)
# 🔍 Fetching records from offset 755000 (Current size: 6252)
# 🔍 Fetching records from offset 756000 (Current size: 6260)
# 🔍 Fetching records from offset 757000 (Current size: 6264)
# 🔍 Fetching records from offset 758000 (Current size: 6269)
# 🔍 Fetching records from offset 759000 (Current size: 6276)
# 🔍 Fetching records from offset 760000 (Current size: 6284)
# 🔍 Fetching records from offset 761000 (Current size: 6288)
# 🔍 Fetching records from offset 762000 (Current size: 6295)
# 🔍 Fetching records from offset 763000 (Current size: 6301)
# 🔍 Fetching records from offset 764000 (Current size: 6310)
# 🔍 Fetching records from offset 765000 (Current size: 6319)
# 🔍 Fetching records from offset 766000 (Current size: 6327)
# 🔍 Fetching records from offset 767000 (Current size: 6336)
# 🔍 Fetching records from offset 768000 (Current size: 6347)
# 🔍 Fetching records from offset 769000 (Current size: 6354)
# 🔍 Fetching records from offset 770000 (Current size: 6360)
# 🔍 Fetching records from offset 771000 (Current size: 6367)
# 🔍 Fetching records from offset 772000 (Current size: 6370)
# 🔍 Fetching records from offset 773000 (Current size: 6382)
# 🔍 Fetching records from offset 774000 (Current size: 6386)
# 🔍 Fetching records from offset 775000 (Current size: 6394)
# 🔍 Fetching records from offset 776000 (Current size: 6407)
# 🔍 Fetching records from offset 777000 (Current size: 6410)
# 🔍 Fetching records from offset 778000 (Current size: 6415)
# 🔍 Fetching records from offset 779000 (Current size: 6427)
# 🔍 Fetching records from offset 780000 (Current size: 6435)
# 🔍 Fetching records from offset 781000 (Current size: 6441)
# 🔍 Fetching records from offset 782000 (Current size: 6450)
# 🔍 Fetching records from offset 783000 (Current size: 6460)
# 🔍 Fetching records from offset 784000 (Current size: 6463)
# 🔍 Fetching records from offset 785000 (Current size: 6467)
# 🔍 Fetching records from offset 786000 (Current size: 6473)
# 🔍 Fetching records from offset 787000 (Current size: 6480)
# 🔍 Fetching records from offset 788000 (Current size: 6484)
# 🔍 Fetching records from offset 789000 (Current size: 6495)
# 🔍 Fetching records from offset 790000 (Current size: 6506)
# 🔍 Fetching records from offset 791000 (Current size: 6515)
# 🔍 Fetching records from offset 792000 (Current size: 6525)
# 🔍 Fetching records from offset 793000 (Current size: 6530)
# 🔍 Fetching records from offset 794000 (Current size: 6535)
# 🔍 Fetching records from offset 795000 (Current size: 6543)
# 🔍 Fetching records from offset 796000 (Current size: 6554)
# 🔍 Fetching records from offset 797000 (Current size: 6558)
# 🔍 Fetching records from offset 798000 (Current size: 6571)
# 🔍 Fetching records from offset 799000 (Current size: 6577)
# 🔍 Fetching records from offset 800000 (Current size: 6578)
# ...
# 🔍 Fetching records from offset 3389000 (Current size: 19359)
# 🔍 Fetching records from offset 3390000 (Current size: 19359)
# 🔍 Fetching records from offset 3391000 (Current size: 19359)
# 🔍 Fetching records from offset 3392000 (Current size: 19359)
# 🔍 Fetching records from offset 3393000 (Current size: 19359)
# 🔍 Fetching records from offset 3394000 (Current size: 19359)
# 🔍 Fetching records from offset 3395000 (Current size: 19359)
# 🔍 Fetching records from offset 3396000 (Current size: 19359)
# 🔍 Fetching records from offset 3397000 (Current size: 19359)
# 🔍 Fetching records from offset 3398000 (Current size: 19359)
# 🔍 Fetching records from offset 3399000 (Current size: 19359)
# 🔍 Fetching records from offset 3400000 (Current size: 19359)
# 🔍 Fetching records from offset 3401000 (Current size: 19359)
# 🔍 Fetching records from offset 3402000 (Current size: 19359)
# 🔍 Fetching records from offset 3403000 (Current size: 19359)
# 🔍 Fetching records from offset 3404000 (Current size: 19359)
# 🔍 Fetching records from offset 3405000 (Current size: 19359)
# 🔍 Fetching records from offset 3406000 (Current size: 19359)
# 🔍 Fetching records from offset 3407000 (Current size: 19359)
# 🔍 Fetching records from offset 3408000 (Current size: 19359)
# 🔍 Fetching records from offset 3409000 (Current size: 19359)
# 🔍 Fetching records from offset 3410000 (Current size: 19359)
# 🔍 Fetching records from offset 3411000 (Current size: 19359)
# 🔍 Fetching records from offset 3412000 (Current size: 19359)
# 🔍 Fetching records from offset 3413000 (Current size: 19359)
# 🔍 Fetching records from offset 3414000 (Current size: 19359)
# 🔍 Fetching records from offset 3415000 (Current size: 19359)
# 🔍 Fetching records from offset 3416000 (Current size: 19359)
# 🔍 Fetching records from offset 3417000 (Current size: 19359)
# 🔍 Fetching records from offset 3418000 (Current size: 19359)
# 🔍 Fetching records from offset 3419000 (Current size: 19359)
# 🔍 Fetching records from offset 3420000 (Current size: 19359)
# 🔍 Fetching records from offset 3421000 (Current size: 19359)
# 🔍 Fetching records from offset 3422000 (Current size: 19359)
# 🔍 Fetching records from offset 3423000 (Current size: 19359)
# 🔍 Fetching records from offset 3424000 (Current size: 19359)
# 🔍 Fetching records from offset 3425000 (Current size: 19359)
# 🔍 Fetching records from offset 3426000 (Current size: 19359)
# 🔍 Fetching records from offset 3427000 (Current size: 19359)
# 🔍 Fetching records from offset 3428000 (Current size: 19359)
# 🔍 Fetching records from offset 3429000 (Current size: 19359)
# 🔍 Fetching records from offset 3430000 (Current size: 19359)
# 🔍 Fetching records from offset 3431000 (Current size: 19359)
# 🔍 Fetching records from offset 3432000 (Current size: 19359)
# 🔍 Fetching records from offset 3433000 (Current size: 19359)
# 🔍 Fetching records from offset 3434000 (Current size: 19359)
# 🔍 Fetching records from offset 3435000 (Current size: 19359)
# 🔍 Fetching records from offset 3436000 (Current size: 19359)
# 🔍 Fetching records from offset 3437000 (Current size: 19359)
# 🔍 Fetching records from offset 3438000 (Current size: 19359)
# 🔍 Fetching records from offset 3439000 (Current size: 19359)
# 🔍 Fetching records from offset 3440000 (Current size: 19359)
# 🔍 Fetching records from offset 3441000 (Current size: 19359)
# 🔍 Fetching records from offset 3442000 (Current size: 19359)
# 🔍 Fetching records from offset 3443000 (Current size: 19359)
# 🔍 Fetching records from offset 3444000 (Current size: 19359)
# 🔍 Fetching records from offset 3445000 (Current size: 19359)
# 🔍 Fetching records from offset 3446000 (Current size: 19359)
# 🔍 Fetching records from offset 3447000 (Current size: 19359)
# 🔍 Fetching records from offset 3448000 (Current size: 19359)
# 🔍 Fetching records from offset 3449000 (Current size: 19359)
# 🔍 Fetching records from offset 3450000 (Current size: 19359)
# 🔍 Fetching records from offset 3451000 (Current size: 19359)
# 🔍 Fetching records from offset 3452000 (Current size: 19359)
# 🔍 Fetching records from offset 3453000 (Current size: 19359)
# 🔍 Fetching records from offset 3454000 (Current size: 19359)
# 🔍 Fetching records from offset 3455000 (Current size: 19359)
# 🔍 Fetching records from offset 3456000 (Current size: 19359)
# 🔍 Fetching records from offset 3457000 (Current size: 19359)
# 🔍 Fetching records from offset 3458000 (Current size: 19359)
# 🔍 Fetching records from offset 3459000 (Current size: 19359)
# 🔍 Fetching records from offset 3460000 (Current size: 19359)
# 🔍 Fetching records from offset 3461000 (Current size: 19359)
# 🔍 Fetching records from offset 3462000 (Current size: 19359)
# 🔍 Fetching records from offset 3463000 (Current size: 19359)
# 🔍 Fetching records from offset 3464000 (Current size: 19359)
# 🔍 Fetching records from offset 3465000 (Current size: 19359)
# 🔍 Fetching records from offset 3466000 (Current size: 19359)
# 🔍 Fetching records from offset 3467000 (Current size: 19451)
# 🔍 Fetching records from offset 3468000 (Current size: 19451)
# 🔍 Fetching records from offset 3469000 (Current size: 19451)
# 🔍 Fetching records from offset 3470000 (Current size: 19451)
# 🔍 Fetching records from offset 3471000 (Current size: 19451)
# 🔍 Fetching records from offset 3472000 (Current size: 19451)
# 🔍 Fetching records from offset 3473000 (Current size: 19451)
# 🔍 Fetching records from offset 3474000 (Current size: 19451)
# 🔍 Fetching records from offset 3475000 (Current size: 19451)
# 🔍 Fetching records from offset 3476000 (Current size: 19451)
# 🔍 Fetching records from offset 3477000 (Current size: 19451)
# 🔍 Fetching records from offset 3478000 (Current size: 19451)
# 🔍 Fetching records from offset 3479000 (Current size: 19451)
# 🔍 Fetching records from offset 3480000 (Current size: 19451)
# 🔍 Fetching records from offset 3481000 (Current size: 19451)
# 🔍 Fetching records from offset 3482000 (Current size: 19451)
# 🔍 Fetching records from offset 3483000 (Current size: 19451)
# 🔍 Fetching records from offset 3484000 (Current size: 19451)
# 🔍 Fetching records from offset 3485000 (Current size: 19451)
# 🔍 Fetching records from offset 3486000 (Current size: 19451)
# 🔍 Fetching records from offset 3487000 (Current size: 19451)
# 🔍 Fetching records from offset 3488000 (Current size: 19451)
# 🔍 Fetching records from offset 3489000 (Current size: 19451)
# 🔍 Fetching records from offset 3490000 (Current size: 19451)
# 🔍 Fetching records from offset 3491000 (Current size: 19451)
# 🔍 Fetching records from offset 3492000 (Current size: 19451)
# 🔍 Fetching records from offset 3493000 (Current size: 19451)
# 🔍 Fetching records from offset 3494000 (Current size: 19451)
# 🔍 Fetching records from offset 3495000 (Current size: 19451)
# 🔍 Fetching records from offset 3496000 (Current size: 19451)
# 🔍 Fetching records from offset 3497000 (Current size: 19451)
# 🔍 Fetching records from offset 3498000 (Current size: 19451)
# 🔍 Fetching records from offset 3499000 (Current size: 19451)
# 🔍 Fetching records from offset 3500000 (Current size: 19451)
# 🔍 Fetching records from offset 3501000 (Current size: 19451)
# 🔍 Fetching records from offset 3502000 (Current size: 19451)
# 🔍 Fetching records from offset 3503000 (Current size: 19451)
# 🔍 Fetching records from offset 3504000 (Current size: 19451)
# 🔍 Fetching records from offset 3505000 (Current size: 19451)
# 🔍 Fetching records from offset 3506000 (Current size: 19451)
# 🔍 Fetching records from offset 3507000 (Current size: 19451)
# 🔍 Fetching records from offset 3508000 (Current size: 19451)
# 🔍 Fetching records from offset 3509000 (Current size: 19451)
# 🔍 Fetching records from offset 3510000 (Current size: 19451)
# 🔍 Fetching records from offset 3511000 (Current size: 19451)
# 🔍 Fetching records from offset 3512000 (Current size: 19451)
# 🔍 Fetching records from offset 3513000 (Current size: 19451)
# 🔍 Fetching records from offset 3514000 (Current size: 19451)
# 🔍 Fetching records from offset 3515000 (Current size: 19451)
# 🔍 Fetching records from offset 3516000 (Current size: 19451)
# 🔍 Fetching records from offset 3517000 (Current size: 19451)
# 🔍 Fetching records from offset 3518000 (Current size: 19451)
# 🔍 Fetching records from offset 3519000 (Current size: 19451)
# 🔍 Fetching records from offset 3520000 (Current size: 19451)
# 🔍 Fetching records from offset 3521000 (Current size: 19451)
# 🔍 Fetching records from offset 3522000 (Current size: 19451)
# 🔍 Fetching records from offset 3523000 (Current size: 19451)
# 🔍 Fetching records from offset 3524000 (Current size: 19451)
# 🔍 Fetching records from offset 3525000 (Current size: 19451)
# 🔍 Fetching records from offset 3526000 (Current size: 19451)
# 🔍 Fetching records from offset 3527000 (Current size: 19451)
# 🔍 Fetching records from offset 3528000 (Current size: 19451)
# 🔍 Fetching records from offset 3529000 (Current size: 19451)
# 🔍 Fetching records from offset 3530000 (Current size: 19451)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       3 while(len(all_data)<NUM_PAIRS):
#       4     print(f"🔍 Fetching records from offset {offset} (Current size: {len(all_data)})")
# ----> 5     data = fetch_data(offset)
#       6     if(data):
#       7         all_data+=(data)
#
# Cell In[12], line 85, in fetch_data(offset)
#      83 """Fetches virus-drug interactions and stores them in a structured dataset."""
#      84 data = []
# ---> 85 activities = get_virus_activity(offset, BATCH_SIZE)
#      86 if not activities:
#      87     return None  # Stop if no more data
#
# Cell In[12], line 36, in get_virus_activity(offset, limit)
#      34 """Fetches activity data and filters for virus targets with IC50 values."""
#      35 url = f"{ACTIVITY_URL}?limit={limit}&offset={offset}"
# ---> 36 response = request_with_retry(url)
#      38 if not response:
#      39     return []  # Return empty list if request fails
#
# Cell In[12], line 21, in request_with_retry(url)
#      19 for attempt in range(RETRY_LIMIT):
#      20     try:
# ---> 21         response = requests.get(url, timeout=10)
#      22         if response.status_code == 200:
#      23             return response  # Return response if successful
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(all_data, columns=["Virus_Organism", "Protein_Sequence", "SMILES", "pIC50"])
# Save to CSV
df.to_csv(r"E:\anti\virus_drug_interactions.csv", index=False)
print("✅ Data saved to virus_drug_interactions.csv")
# Out:
# ✅ Data saved to virus_drug_interactions.csv
